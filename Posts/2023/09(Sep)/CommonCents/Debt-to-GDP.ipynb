# %%
import matplotlib.pyplot as plt
import numpy             as np
import pandas            as pd

# %%
d2g = pd.read_csv('debt_to_gdp_percentage.csv')

# %%
d2g
# Out:
#      Date        D2G
# 0    1790   29.60000
# 1    1791   29.20000
# 2    1792   28.00000
# 3    1793   24.40000
# 4    1794   21.80000
# ..    ...        ...
# 228  2018  104.52559
# 229  2019  106.02650
# 230  2020  127.73929
# 231  2021  121.74781
# 232  2022  121.11274
#
# [233 rows x 2 columns]

# %%
fig = plt.figure(figsize=(14,7))
ax  = fig.add_subplot(1,1,1)
ax.set_facecolor("#aaaaaa")
ax.plot(d2g['Date'],d2g['D2G'],color="#f5f5dc")
ax.fill_between(d2g['Date'],d2g['D2G'],y2=0,color="#f5f5dc")
ax.grid('on',color="#888")
ax.set_xlabel('Year',fontsize=16)
ax.set_ylabel('Debt to GDP Percentage',fontsize=16)
ax.set_ylim([0,140])
#ax.set_xlim([1790,1920])
#fig.savefig('D2G_1790-to_2022.png')

# %%
fig = plt.figure(figsize=(14,7))
ax  = fig.add_subplot(1,1,1)
ax.set_facecolor("#aaaaaa")
ax.plot(d2g['Date'],d2g['D2G'],color="#f5f5dc")
ax.fill_between(d2g['Date'],d2g['D2G'],y2=0,color="#f5f5dc")
ax.grid('on',color="#888")
ax.set_xlabel('Year',fontsize=16)
ax.set_ylabel('Debt to GDP Percentage',fontsize=16)
ax.set_ylim([0,140])
ax.set_xlim([1790,1929])
#fig.savefig('D2G_1790-to_1929.png')

# %%
fig = plt.figure(figsize=(14,7))
ax  = fig.add_subplot(1,1,1)
ax.set_facecolor("#aaaaaa")
ax.plot(d2g['Date'],d2g['D2G'],color="#f5f5dc")
ax.fill_between(d2g['Date'],d2g['D2G'],y2=0,color="#f5f5dc")
ax.grid('on',color="#888")
ax.set_xlabel('Year',fontsize=16)
ax.set_ylabel('Debt to GDP Percentage',fontsize=16)
ax.set_ylim([0,140])
ax.set_xlim([1929,2023])
#fig.savefig('D2G_1929-to_2022.png')

# %%
d2g['Date'].iloc[0:140]
# Out:
# 0      1790
# 1      1791
# 2      1792
# 3      1793
# 4      1794
#        ...
# 135    1925
# 136    1926
# 137    1927
# 138    1928
# 139    1929
# Name: Date, Length: 140, dtype: int64

# %%
np.trapz(d2g['D2G'].iloc[0:140])/139
# Out:
# 11.160791366906475

# %%
np.trapz(d2g['D2G'].iloc[140:])/(232-140)
# Out:
# 60.75140641304347

# %%
np.mean(d2g['D2G'])
# Out:
# 31.03663416309012

# %%
np.mean(d2g['D2G'].iloc[0:140])
# Out:
# 11.24

# %%
np.mean(d2g['D2G'].iloc[140:])
# Out:
# 60.83801892473117

# %%
d2g[d2g['Date']>1960][25:]
# Out:
#      Date        D2G
# 196  1986   46.30286
# 197  1987   48.31918
# 198  1988   49.67308
# 199  1989   50.83328
# 200  1990   53.76862
# 201  1991   58.43008
# 202  1992   61.37422
# 203  1993   63.43898
# 204  1994   63.71826
# 205  1995   64.40788
# 206  1996   64.18211
# 207  1997   62.59595
# 208  1998   60.44699
# 209  1999   58.20164
# 210  2000   54.90905
# 211  2001   54.52598
# 212  2002   56.71460
# 213  2003   59.00606
# 214  2004   60.19957
# 215  2005   60.62720
# 216  2006   61.17295
# 217  2007   61.83888
# 218  2008   67.61133
# 219  2009   82.02683
# 220  2010   89.89851
# 221  2011   94.64394
# 222  2012   98.75064
# 223  2013   99.26501
# 224  2014  101.38919
# 225  2015   99.52805
# 226  2016  104.51666
# 227  2017  103.73954
# 228  2018  104.52559
# 229  2019  106.02650
# 230  2020  127.73929
# 231  2021  121.74781
# 232  2022  121.11274

# %%
232-140
# Out:
# 92
