# %%
import matplotlib           as mpl
import matplotlib.pyplot    as plt
import mpl_toolkits.mplot3d as mpl3
import matplotlib.cm        as cm
import matplotlib.ticker    as mpt
import numpy                as np
#import Axes3D

# %%
def d1(x,y,z,mu):
    return np.sqrt( (x+mu)**2 + y**2 + z**2 )

def d2(x,y,z,mu):
    return np.sqrt( (x-1+mu)**2 + y**2 + z**2)

def U_Jacobi(x,y,z,mu,cutoff):
    u = 0.5*(x**2+y**2) + (1-mu)/d1(x,y,z,mu) + mu/d2(x,y,z,mu)
    u[np.where(u>cutoff)] = cutoff
    return u

# %%
sun_mass   = 1.989e30
earth_mass = 5.972e24
moon_mass  = 7.350e22
mu_SEM     = (earth_mass + moon_mass)/(sun_mass + earth_mass + moon_mass)
mu_SJ      = 0.001
display(mu_SEM)
# Out:
# 3.039457830546851e-06

# %%
mu      = 0.5
xmin, xmax, ymin, ymax = -1.5,1.5,-1.5,1.5
delta_x = 0.001
delta_y = 0.001
z_val   = 0.0
x = np.arange(xmin,xmax+delta_x,delta_x)
y = np.arange(ymin,ymax+delta_y,delta_y)
X, Y = np.meshgrid(x,y)
Z    = U_Jacobi(X,Y,z_val,mu,4.5)
# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Plot the surface
Uxy = ax.plot_surface(X, Y, Z, cmap='Greens_r',edgecolor='none', linewidth=0, antialiased=False)
#ax.set_zlim([-1,5])
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
ax.set_zlabel(r'$U(x,y,%s)$'%z_val)
# Add a color bar
fig.colorbar(Uxy)#
# Show the plot
plt.show()

# %%
xmin, xmax, ymin, ymax = -1.5,1.5,-1.5,1.5
delta_x = 0.01
delta_y = 0.01
z_val   = 0.0
x = np.arange(xmin,xmax+delta_x,delta_x)
y = np.arange(ymin,ymax+delta_y,delta_y)
X, Y = np.meshgrid(x,y)
Z    = U_Jacobi(X,Y,z_val,mu,4.5)
fig_con = plt.figure(figsize=(5,5))
ax_con  = fig_con.add_subplot(111)
my_levels = [1.4,1.45,1.5,1.55,1.6,1.65,1.7,1.75,1.8]
cons    = ax_con.contour(X,Y,Z,levels=my_levels,linewidths=2.0, cmap='Greens_r')
ax_con.set_facecolor(color=[0.7,0.7,0.7])
ax_con.clabel(cons, inline=True, fontsize=8, fmt="%.2f")
ax_con.set_xlabel(r'$x$')
ax_con.set_ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
mu      = 0.05
xmin, xmax, ymin, ymax = -1.5,1.5,-1.5,1.5
delta_x = 0.01
delta_y = 0.01
z_val   = 0.0
x = np.arange(xmin,xmax+delta_x,delta_x)
y = np.arange(ymin,ymax+delta_y,delta_y)
X, Y = np.meshgrid(x,y)
Z    = U_Jacobi(X,Y,z_val,mu,4.5)
# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Plot the surface
Uxy = ax.plot_surface(X, Y, Z, cmap='Greens_r',edgecolor='none', linewidth=0, antialiased=False)
#ax.set_zlim([-1,5])
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
ax.set_zlabel(r'$U(x,y,%s)$'%z_val)
# Add a color bar
fig.colorbar(Uxy)#
# Show the plot
plt.show()

# %%
xmin, xmax, ymin, ymax = -1.5,1.5,-1.5,1.5
delta_x = 0.01
delta_y = 0.01
z_val   = 0.0
x = np.arange(xmin,xmax+delta_x,delta_x)
y = np.arange(ymin,ymax+delta_y,delta_y)
X, Y = np.meshgrid(x,y)
Z    = U_Jacobi(X,Y,z_val,mu,4.5)
fig_con = plt.figure(figsize=(5,5))
ax_con  = fig_con.add_subplot(111)
my_levels = [1.4,1.45,1.5,1.55,1.6,1.65,1.7,1.75,1.8]
cons    = ax_con.contour(X,Y,Z,levels=my_levels,linewidths=2.0, cmap='Greens_r')
ax_con.set_facecolor(color=[0.7,0.7,0.7])
ax_con.clabel(cons, inline=True, fontsize=8, fmt="%.2f")
ax_con.set_xlabel(r'$x$')
ax_con.set_ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
mu      = 0.05
Delta = 1.5
xmin, xmax, ymin, ymax = -Delta,Delta,-Delta,Delta
delta_x = 0.001
delta_y = 0.001
z_val   = 0.0
x = np.arange(xmin,xmax+delta_x,delta_x)
y = np.arange(ymin,ymax+delta_y,delta_y)
X, Y = np.meshgrid(x,y)
Z    = U_Jacobi(X,Y,z_val,mu,1000)
fig_con = plt.figure(figsize=(5,5))
ax_con  = fig_con.add_subplot(111)
cons    = ax_con.contour(X,Y,Z,levels=[1.5,1.55,1.6,1.65,1.7,1.75],linewidths=2.0, cmap='Greens_r')
#ax_con.set_facecolor(color=[0.7,0.7,0.7])
ax_con.clabel(cons, inline=True, fontsize=8, fmt="%.2f")
ax_con.set_xlabel(r'$x$')
ax_con.set_ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
np.min(Z)
# Out:
# np.float64(1.4999985138177607)

# %%
fig_con = plt.figure(figsize=(5,5))
ax_con  = fig_con.add_subplot(111)
cons    = ax_con.contour(X,Y,Z,levels=[1.5,2.0,2.5,3.0,3.5,4.0],linewidths=2.0, cmap='Greens_r')
ax_con.clabel(cons, inline=True, fontsize=8, fmt="%.2f")
ax_con.set_xlabel(r'$x$')
ax_con.set_ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
fig_con = plt.figure(figsize=(5,5))
ax_con  = fig_con.add_subplot(111)
cons    = ax_con.contourf(X,Y,Z,levels=[1.5,2.0,2.5,3.0,3.5,4.0],linewidths=2.0, cmap='Greens_r')
ax_con.clabel(cons, inline=True, fontsize=8, fmt="%.2f")
ax_con.set_xlabel(r'$x$')
ax_con.set_ylabel(r'$y$')

# %%
mu      = 0.5
delta_x = 0.05
delta_y = 0.05
x = np.arange(-2*mu,2*mu+delta_x,delta_x)
y = np.arange(-2*mu,2*mu+delta_y,delta_y)
X, Y = np.meshgrid(x,y)
Z    = -U_Jacobi(X,0,Z,mu,3)
# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_zlim([-1,5])
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$z$')
ax.set_zlabel(r'$U(x,0,z)$')
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 7
#       5 y = np.arange(-2*mu,2*mu+delta_y,delta_y)
#       6 X, Y = np.meshgrid(x,y)
# ----> 7 Z    = -U_Jacobi(X,0,Z,mu,3)
#       8 # Create a figure and a 3D axis
#       9 fig = plt.figure()
#
# Cell In[2], line 8, in U_Jacobi(x, y, z, mu, cutoff)
#       7 def U_Jacobi(x,y,z,mu,cutoff):
# ----> 8     u = 0.5*(x**2+y**2) + (1-mu)/d1(x,y,z,mu) + mu/d2(x,y,z,mu)
#       9     u[np.where(u>cutoff)] = cutoff
#      10     return u
#
# Cell In[2], line 2, in d1(x, y, z, mu)
#       1 def d1(x,y,z,mu):
# ----> 2     return np.sqrt( (x+mu)**2 + y**2 + z**2 )
#
# ValueError: operands could not be broadcast together with shapes (41,41) (3001,3001)

# %%
mu      = 0.5
delta_x = 0.05
delta_y = 0.05
x = np.arange(-2*mu,2*mu+delta_x,delta_x)
y = np.arange(-2*mu,2*mu+delta_y,delta_y)
X, Y = np.meshgrid(x,y)
Z    = -U_Jacobi(-1,Y,Z,mu,6)
# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis')
#ax.set_zlim([-1,5])
ax.set_xlabel(r'$y$')
ax.set_ylabel(r'$z$')
ax.set_zlabel(r'$U(0,y,z)$')
# Show the plot
plt.show()

# %%
# Generate data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis')
# Show the plot
plt.show()

# %%
# Generate data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface with customizations
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Customize the z-axis
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(mpt.LinearLocator(10))
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar
fig.colorbar(surf, shrink=0.5, aspect=5)

# Show the plot
plt.show()

# %%
# Create surface data
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
X, Y = np.meshgrid(x, y)
Z = np.cos(np.pi * X) * np.sin(np.pi * Y)

# Compute normals
dx, dy = np.gradient(Z)
normals = np.dstack((-dx, -dy, np.ones_like(Z)))
normals /= np.linalg.norm(normals, axis=2)[:, :, np.newaxis]

# Light and view directions
light_dir = np.array([0, 0, 1])  # from above
view_dir = np.array([0, 0, 1])   # looking straight down

# Phong reflection parameters
ambient = 0.2
diffuse_coeff = 0.7
specular_coeff = 0.5
shininess = 20

# Diffuse term
diffuse = diffuse_coeff * np.clip(np.sum(normals * light_dir, axis=2), 0, 1)

# Specular term
reflect_dir = 2 * np.sum(normals * light_dir, axis=2)[:, :, np.newaxis] * normals - light_dir
specular = specular_coeff * np.clip(np.sum(reflect_dir * view_dir, axis=2), 0, 1) ** shininess

# Final color intensity
intensity = ambient + diffuse + specular
intensity = np.clip(intensity, 0, 1)

# Plot with custom colors
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, facecolors=plt.cm.viridis(intensity), rstride=1, cstride=1, linewidth=0, antialiased=False)
ax.set_title("Phong-like Shading in Matplotlib")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create grid and data
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)
# Create contour plot with specific interval
levels = np.arange(-1, 1.1, 0.2)
CS = plt.contour(X, Y, Z, levels=levels, colors='black')
# Add labels to contours
plt.clabel(CS, inline=True, fontsize=8, fmt="%.2f")
plt.title("Contour Plot with Interval Labels")
plt.show()
