# %%
import sympy as sym
sym.init_printing()

# %%
# Symbols
t    = sym.symbols('t', real=True)
a, b = sym.symbols('a b', constant=True)

# Functions
f = sym.Function('f')
g = sym.Function('g')

# %%
type(a)
# Out:
# sympy.core.symbol.Symbol

# %%
type(f)
# Out:
# sympy.core.function.UndefinedFunction

# %%
my_expr = a*f(t) + b*g(t)

# %%
type(my_expr)
# Out:
# sympy.core.add.Add

# %%
my_expr.args
# Out:
# (a⋅f(t), b⋅g(t))

# %%
type(my_expr.args[0])
# Out:
# sympy.core.mul.Mul
